# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import time
sys.path.append('/'.join(sys.path[0].split('/')[:-1]))

from modules.full_pipeline_multiple_steps import main

# %% [markdown]
# ### Train long connections 4 steps variable weights (increasing)

# %%
{
    "directories":
            {
            "datadir": "../data/healpix/",
            "input_dir": "5.625deg_nearest/",
            "model_save_path": "models/",
            "pred_save_path": "predictions/",
            "obs_file_name": "observations_nearest.nc",
            "rmse_weyn_name": "metrics/rmses_weyn.nc",
            "constants": "constants/constants_5.625deg_standardized.nc",
            "train_mean_file": "mean_train_features_dynamic.nc",
            "train_std_file": "std_train_features_dynamic.nc",
            "metrics_path": "metrics/",
            "standardized_data": "None"
            },
    "training_constants":
    {
            "chunk_size": 521,
            "train_years": ["1990","2012"],
            "val_years": ["2013", "2016"],
            "test_years": ["2017", "2018"],
            "nodes":3072,
            "max_lead_time": 120,
            "nb_timesteps": 2,
            "nb_epochs": 12,
            "learning_rate": 0.008,
            "batch_size": 24
    },
    "model_parameters":
    {
            "len_sqce": 2,
            "delta_t": 6,
            "in_features": 7,
            "out_features":2,
            "architecture_name": "loss_v0_4steps_variation0_residual_l3_long_connections_per_epoch",
            "resolution": 5.625,
            "kernel_size_pooling": 4,
            "initial_weights": [1, 0,0,0],
            "model": "UNetSphericalHealpixResidualLongConnections"
    }
}

# %%
train_loss_ev, val_loss_ev, train_loss_steps_ev, test_loss_steps_ev, weight_variations_ev = \
main('config_residual_multiple_steps.json', load_model=False)
# Out:
# Loading data to RAM...
# Time: 26.71s
# Loading data to RAM...
# Time: 4.33s
# Define model...
# Model name:  all_const_len2_delta_6_architecture_loss_v0_4steps_variation0_residual_l3_long_connections_per_epoch
# Starting epoch 1
# Time initial steps: 0.001s
# Batch idx: 8350; Loss: 0.108 - Other 0.00002 - 3123Epoch:   1/  1  - loss: 0.108  - val_loss: 0.06354  - time: 7975.842962
# Starting epoch 2
# Time initial steps: 0.005s
# Batch idx: 8350; Loss: 0.055 - Other 0.00000 - 7052Epoch:   1/  1  - loss: 0.055  - val_loss: 0.05531  - time: 7980.530294
# Starting epoch 3
# Time initial steps: 0.006s
# Batch idx: 8350; Loss: 0.047 - Other 0.00000 - 7734Epoch:   1/  1  - loss: 0.047  - val_loss: 0.05327  - time: 8014.607294
# Starting epoch 4
# Time initial steps: 0.004s
# Batch idx: 8350; Loss: 0.043 - Other 0.00000 - 2035Epoch:   1/  1  - loss: 0.043  - val_loss: 0.04867  - time: 8004.749501
# Starting epoch 5
# Time initial steps: 0.006s
# Batch idx: 8350; Loss: 0.041 - Other 0.00000 - 4753Epoch:   1/  1  - loss: 0.041  - val_loss: 0.04644  - time: 8000.324136
# Starting epoch 6
# Time initial steps: 0.008s
# Batch idx: 8350; Loss: 0.039 - Other 0.00000 - 4656Epoch:   1/  1  - loss: 0.039  - val_loss: 0.04832  - time: 7964.428326
# Starting epoch 7
# Time initial steps: 0.005s
# Batch idx: 8350; Loss: 0.038 - Other 0.00000 - 5290Epoch:   1/  1  - loss: 0.038  - val_loss: 0.04541  - time: 7915.412110
# Starting epoch 8
# Time initial steps: 0.006s
# Batch idx: 8350; Loss: 0.037 - Other 0.00000 - 5712Epoch:   1/  1  - loss: 0.037  - val_loss: 0.04557  - time: 7995.396779
# Starting epoch 9
# Time initial steps: 0.006s
# Batch idx: 8200; Loss: 0.036 - Other 0.00000 - 5687

# %% [markdown]
# ## Constant weights with increasing importance

# %%
{
    "directories":
            {
            "datadir": "../data/healpix/",
            "input_dir": "5.625deg_nearest/",
            "model_save_path": "models/",
            "pred_save_path": "predictions/",
            "obs_file_name": "observations_nearest.nc",
            "rmse_weyn_name": "metrics/rmses_weyn.nc",
            "constants": "constants/constants_5.625deg_standardized.nc",
            "train_mean_file": "mean_train_features_dynamic.nc",
            "train_std_file": "std_train_features_dynamic.nc",
            "metrics_path": "metrics/",
            "standardized_data": "None"
            },
    "training_constants":
    {
            "chunk_size": 521,
            "train_years": ["1990","2012"],
            "val_years": ["2013", "2016"],
            "test_years": ["2017", "2018"],
            "nodes":3072,
            "max_lead_time": 120,
            "nb_timesteps": 2,
            "nb_epochs": 12,
            "learning_rate": 0.008,
            "batch_size": 15
    },
    "model_parameters":
    {
            "len_sqce": 2,
            "delta_t": 6,
            "in_features": 7,
            "out_features":2,
            "num_steps_ahead": 8,
            "architecture_name": "loss_v0_8steps_constant_increasing_l3_per_epoch",
            "resolution": 5.625,
            "kernel_size_pooling": 4,
            "initial_weights": [1,2,3,4,5,6,7,8],
            "model": "UNetSphericalHealpixResidualShort3LevelsOnlyEncoder"
    }
}
# Out:
# {'directories': {'datadir': '../data/healpix/',
#   'input_dir': '5.625deg_nearest/',
#   'model_save_path': 'models/',
#   'pred_save_path': 'predictions/',
#   'obs_file_name': 'observations_nearest.nc',
#   'rmse_weyn_name': 'metrics/rmses_weyn.nc',
#   'constants': 'constants/constants_5.625deg_standardized.nc',
#   'train_mean_file': 'mean_train_features_dynamic.nc',
#   'train_std_file': 'std_train_features_dynamic.nc',
#   'metrics_path': 'metrics/',
#   'standardized_data': 'None'},
#  'training_constants': {'chunk_size': 521,
#   'train_years': ['1990', '2012'],
#   'val_years': ['2013', '2016'],
#   'test_years': ['2017', '2018'],
#   'nodes': 3072,
#   'max_lead_time': 120,
#   'nb_timesteps': 2,
#   'nb_epochs': 12,
#   'learning_rate': 0.008,
#   'batch_size': 15},
#  'model_parameters': {'len_sqce': 2,
#   'delta_t': 6,
#   'in_features': 7,
#   'out_features': 2,
#   'num_steps_ahead': 8,
#   'architecture_name': 'loss_v0_8steps_constant_increasing_l3_per_epoch',
#   'resolution': 5.625,
#   'kernel_size_pooling': 4,
#   'initial_weights': [1, 2, 3, 4, 5, 6, 7, 8],
#   'model': 'UNetSphericalHealpixResidualShort3LevelsOnlyEncoder'}}

# %%
train_loss_ev, val_loss_ev, train_loss_steps_ev, test_loss_steps_ev, weight_variations_ev = \
main('config_residual_multiple_steps.json', load_model=False)
# Out:
# Loading data to RAM...
# Time: 36.68s
# Loading data to RAM...
# Time: 6.10s
# Define model...
# Model name:  all_const_len2_delta_6_architecture_loss_v0_8steps_constant_increasing_l3_per_epoch
# Starting epoch 1
# Time initial steps: 0.003s
# Batch idx: 13400; Loss: 0.135 - Other 0.00001 - 62556Epoch:   1/  1  - loss: 0.135  - val_loss: 0.10098  - time: 15557.203844
# Starting epoch 2
# Time initial steps: 0.009s
# Batch idx: 13400; Loss: 0.078 - Other 0.00000 - 11479Epoch:   1/  1  - loss: 0.078  - val_loss: 0.08723  - time: 15250.359599
# Starting epoch 3
# Time initial steps: 0.006s
# Batch idx: 13400; Loss: 0.068 - Other 0.00000 - 3375Epoch:   1/  1  - loss: 0.068  - val_loss: 0.09058  - time: 15554.730720
# Starting epoch 4
# Time initial steps: 0.006s
# Batch idx: 13400; Loss: 0.063 - Other 0.00000 - 4263Epoch:   1/  1  - loss: 0.063  - val_loss: 0.07350  - time: 15316.156153
# Starting epoch 5
# Time initial steps: 0.005s
# Batch idx: 13400; Loss: 0.060 - Other 0.00000 - 6041Epoch:   1/  1  - loss: 0.060  - val_loss: 0.06955  - time: 15201.103510
# Starting epoch 6
# Time initial steps: 0.006s
# Batch idx: 13400; Loss: 0.057 - Other 0.00000 - 6552

# %%
import json
import numpy as np

best_epoch = np.argmin(val_loss_ev)
min_error = val_loss_ev[best_epoch]

from modules.mail import send_info_mail

# %%
train_loss_json = '../data/healpix/models/train_loss_'  + '8steps_constant_increasing_l3_per_epoch' + '.json'
with open(train_loss_json, "w") as outfile:  
    json.dump(train_loss_steps_ev, outfile)
    
test_loss_json = '../data/healpix/models/test_loss_'  + '8steps_constant_increasing_l3_per_epoch' + '.json'
with open(test_loss_json, "w") as outfile:  
    json.dump(test_loss_steps_ev, outfile)

with open("../modules/confMail.json") as json_data_file:
    mailConf = json.load(json_data_file)

mail = {
    "sender": mailConf["sender"],
    "receiver": mailConf["sender"],
    "subject": "Finished training!",
    "body": "Finished training model {}.\n Min loss {} at epoch {} " \
        .format(description, min_error, best_epoch),
    "fileAttaching": "Yes",
    "file": [train_loss_json, test_loss_json]

}
send_info_mail(mailInfo=mail, configFile=mailConf)

# %% [markdown]
# ## Idem but with long connections

# %%
{
    "directories":
            {
            "datadir": "../data/healpix/",
            "input_dir": "5.625deg_nearest/",
            "model_save_path": "models/",
            "pred_save_path": "predictions/",
            "obs_file_name": "observations_nearest.nc",
            "rmse_weyn_name": "metrics/rmses_weyn.nc",
            "constants": "constants/constants_5.625deg_standardized.nc",
            "train_mean_file": "mean_train_features_dynamic.nc",
            "train_std_file": "std_train_features_dynamic.nc",
            "metrics_path": "metrics/",
            "standardized_data": "None"
            },
    "training_constants":
    {
            "chunk_size": 521,
            "train_years": ["1990","2012"],
            "val_years": ["2013", "2016"],
            "test_years": ["2017", "2018"],
            "nodes":3072,
            "max_lead_time": 120,
            "nb_timesteps": 2,
            "nb_epochs": 12,
            "learning_rate": 0.008,
            "batch_size": 15
    },
    "model_parameters":
    {
            "len_sqce": 2,
            "delta_t": 6,
            "in_features": 7,
            "out_features":2,
            "num_steps_ahead": 8,
            "architecture_name": "loss_v0_8steps_constant_increasing_static_l3_long_connections_per_epoch",
            "resolution": 5.625,
            "kernel_size_pooling": 4,
            "initial_weights": [1,2,3,4,5,6,7,8],
            "model": "UNetSphericalHealpixResidualLongConnections"
    }
}
# Out:
# {'directories': {'datadir': '../data/healpix/',
#   'input_dir': '5.625deg_nearest/',
#   'model_save_path': 'models/',
#   'pred_save_path': 'predictions/',
#   'obs_file_name': 'observations_nearest.nc',
#   'rmse_weyn_name': 'metrics/rmses_weyn.nc',
#   'constants': 'constants/constants_5.625deg_standardized.nc',
#   'train_mean_file': 'mean_train_features_dynamic.nc',
#   'train_std_file': 'std_train_features_dynamic.nc',
#   'metrics_path': 'metrics/',
#   'standardized_data': 'None'},
#  'training_constants': {'chunk_size': 521,
#   'train_years': ['1990', '2012'],
#   'val_years': ['2013', '2016'],
#   'test_years': ['2017', '2018'],
#   'nodes': 3072,
#   'max_lead_time': 120,
#   'nb_timesteps': 2,
#   'nb_epochs': 12,
#   'learning_rate': 0.008,
#   'batch_size': 15},
#  'model_parameters': {'len_sqce': 2,
#   'delta_t': 6,
#   'in_features': 7,
#   'out_features': 2,
#   'num_steps_ahead': 8,
#   'architecture_name': 'loss_v0_8steps_constant_increasing_static_l3_long_connections_per_epoch',
#   'resolution': 5.625,
#   'kernel_size_pooling': 4,
#   'initial_weights': [1, 2, 3, 4, 5, 6, 7, 8],
#   'model': 'UNetSphericalHealpixResidualLongConnections'}}

# %%
train_loss_ev, val_loss_ev, train_loss_steps_ev, test_loss_steps_ev, weight_variations_ev = \
main('config_residual_multiple_steps.json', load_model=False)
# Out:
# Loading data to RAM...
# Time: 33.00s
# Loading data to RAM...
# Time: 5.34s
# Define model...
# Model name:  all_const_len2_delta_6_architecture_loss_v0_8steps_constant_increasing_static_l3_long_connections_per_epoch
# Starting epoch 1
# Time initial steps: 0.006s
# Batch idx: 13400; Loss: 0.131 - Other 0.00001 - 8557Epoch:   1/  1  - loss: 0.131  - val_loss: 0.08834  - time: 15324.984318
# Starting epoch 2
# Time initial steps: 0.009s
# Batch idx: 13400; Loss: 0.075 - Other 0.00000 - 11487Epoch:   1/  1  - loss: 0.075  - val_loss: 0.07641  - time: 15183.495890
# Starting epoch 3
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.065 - Other 0.00000 - 23899Epoch:   1/  1  - loss: 0.065  - val_loss: 0.06845  - time: 15190.959196
# Starting epoch 4
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.061 - Other 0.00000 - 5621Epoch:   1/  1  - loss: 0.061  - val_loss: 0.06935  - time: 15179.658413
# Starting epoch 5
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.058 - Other 0.00000 - 6870Epoch:   1/  1  - loss: 0.057  - val_loss: 0.06846  - time: 15194.732501
# Starting epoch 6
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.055 - Other 0.00000 - 7779Epoch:   1/  1  - loss: 0.055  - val_loss: 0.05948  - time: 15188.754483
# Starting epoch 7
# Time initial steps: 0.005s
# Batch idx: 13400; Loss: 0.054 - Other 0.00000 - 9266Epoch:   1/  1  - loss: 0.054  - val_loss: 0.05411  - time: 15240.910362
# Starting epoch 8
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.052 - Other 0.00000 - 8245Epoch:   1/  1  - loss: 0.052  - val_loss: 0.05353  - time: 15537.308484
# Starting epoch 9
# Time initial steps: 0.006s
# Batch idx: 13400; Loss: 0.051 - Other 0.00000 - 7678Epoch:   1/  1  - loss: 0.051  - val_loss: 0.05765  - time: 15665.068248
# Starting epoch 10
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.050 - Other 0.00000 - 8963Epoch:   1/  1  - loss: 0.050  - val_loss: 0.05879  - time: 15431.016281
# Starting epoch 11
# Time initial steps: 0.003s
# Batch idx: 13400; Loss: 0.050 - Other 0.00000 - 9427Epoch:   1/  1  - loss: 0.050  - val_loss: 0.05627  - time: 15864.884509
# Starting epoch 12
# Time initial steps: 0.001s
# Batch idx: 13400; Loss: 0.049 - Other 0.00000 - 9284Epoch:   1/  1  - loss: 0.049  - val_loss: 0.05392  - time: 15739.066462

# %%
for w in weight_variations_ev:
    for new_w in w:
        print('Epoch {} - Iteration {}'.format(new_w[1], new_w[2]))
        print('WEIGHT VECTOR: ', new_w[0])
# Out:
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 2874
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 12546
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 1534
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 12253
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 642
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 11012
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 863
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 7780
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 956
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 6531
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 411
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 835
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 5622
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 825
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 4135
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 655
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 5156
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 653
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 5723
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 829
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 4438
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 719
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 3974
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 0
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 207
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 409
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 653
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
# Epoch 0 - Iteration 4117
# WEIGHT VECTOR:  [0.02777778 0.05555556 0.08333333 0.11111111 0.13888889 0.16666667
#  0.19444444 0.22222222]
